# %% [markdown]
# # My Jupiter Notebook on IBM Watson Studio

# %% [markdown]
# **Yen Dinh**
#
# Environmental Assessor
#
# Desired occupation: Data Scientist in Climate Change Research

# %% [markdown]
# *I am  interested in data science because I want to provide stakeholders valuable information to make more sustainable business decisions.*

# %% [markdown]
# ### My code is supposed to say hello to you

# %%
print("Hello, it's nice to meet you :)")
# Out:
# Hello, it's nice to meet you :)

# %% [markdown]
# * Have a nice day!
#
# ###### Recipe for Happiness:
# 1. Bag of smiles
# 2. lbs of positivity
# 3. Cups of good humor
# 4. Cups of sharing
# 5. Cups of self-esteem
# 6. Spoons of simplicity
# 7. Drops of easy-going
# 8. Packets of life loving
#
# ![photo-1597848212624-a19eb35e2651.jpg](attachment:photo-1597848212624-a19eb35e2651.jpg)
#
# ***
